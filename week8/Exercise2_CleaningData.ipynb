# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# # Handling with missing data

# %%
# Drop id and use dataframe index
df = df.drop("id", axis=1)
df
# Out:
#                 full_name  first_name    last_name  \
# 0         Mariel Finnigan      Mariel     Finnigan
# 1           Kenyon Possek      Kenyon       Possek
# 2          Lalo Manifould        Lalo    Manifould
# 3          Nickola Carous     Nickola       Carous
# 4           Norman Dubbin      Norman       Dubbin
# 5            Hasty Perdue       Hasty       Perdue
# 6          Franz Castello       Franz     Castello
# 7            Jorge Tarney       Jorge       Tarney
# 8      Eunice Blakebrough      Eunice  Blakebrough
# 9   Kristopher Frankcombe  Kristopher   Frankcombe
# 10           Palm Domotor        Palm      Domotor
# 11          Luz Lansdowne         Luz    Lansdowne
# 12         Modestia Keble    Modestia        Keble
# 13           Stacee Bovis      Stacee        Bovis
# 14              Eden Wace        Eden         Wace
# 15              Eden Wace        Eden         Wace
# 16        Tobias Sherburn      Tobias     Sherburn
# ...

# %%
# Drop all columns where all values NaN
df = df.dropna(how='all')
df
# Out:
#                 full_name  first_name    last_name  \
# 0         Mariel Finnigan      Mariel     Finnigan
# 1           Kenyon Possek      Kenyon       Possek
# 2          Lalo Manifould        Lalo    Manifould
# 3          Nickola Carous     Nickola       Carous
# 4           Norman Dubbin      Norman       Dubbin
# 5            Hasty Perdue       Hasty       Perdue
# 6          Franz Castello       Franz     Castello
# 7            Jorge Tarney       Jorge       Tarney
# 8      Eunice Blakebrough      Eunice  Blakebrough
# 9   Kristopher Frankcombe  Kristopher   Frankcombe
# 10           Palm Domotor        Palm      Domotor
# 11          Luz Lansdowne         Luz    Lansdowne
# 12         Modestia Keble    Modestia        Keble
# 13           Stacee Bovis      Stacee        Bovis
# 14              Eden Wace        Eden         Wace
# 15              Eden Wace        Eden         Wace
# 16        Tobias Sherburn      Tobias     Sherburn
# ...

# %%
# Drop Duplicate Content (Eden Wace)
df = df.drop_duplicates()
df = df.reset_index(drop=True)
df
# Out:
#                 full_name  first_name    last_name  \
# 0         Mariel Finnigan      Mariel     Finnigan
# 1           Kenyon Possek      Kenyon       Possek
# 2          Lalo Manifould        Lalo    Manifould
# 3          Nickola Carous     Nickola       Carous
# 4           Norman Dubbin      Norman       Dubbin
# 5            Hasty Perdue       Hasty       Perdue
# 6          Franz Castello       Franz     Castello
# 7            Jorge Tarney       Jorge       Tarney
# 8      Eunice Blakebrough      Eunice  Blakebrough
# 9   Kristopher Frankcombe  Kristopher   Frankcombe
# 10           Palm Domotor        Palm      Domotor
# 11          Luz Lansdowne         Luz    Lansdowne
# 12         Modestia Keble    Modestia        Keble
# 13           Stacee Bovis      Stacee        Bovis
# 14              Eden Wace        Eden         Wace
# 15        Tobias Sherburn      Tobias     Sherburn
# 16         Clair Skillern       Clair     Skillern
# ...

# %%
# Age
# Check if there is a number or other things 
c=0
for row in df['age']:
    try:
        int(row)
        # Check if Age is older than 0
        if (int(row) < 0):
            df.loc[c, 'age']=np.nan
    except ValueError:
        # If no number change to NaN
        df.loc[c, 'age']=np.nan
        pass
   
    c+=1

# Age (Missing Age => old and minus Age)
# Fill the NaN with the Median in the age column
df['age'] = df['age'].fillna(int(df['age'].median()))
df
# Out:
#                 full_name  first_name    last_name  \
# 0         Mariel Finnigan      Mariel     Finnigan
# 1           Kenyon Possek      Kenyon       Possek
# 2          Lalo Manifould        Lalo    Manifould
# 3          Nickola Carous     Nickola       Carous
# 4           Norman Dubbin      Norman       Dubbin
# 5            Hasty Perdue       Hasty       Perdue
# 6          Franz Castello       Franz     Castello
# 7            Jorge Tarney       Jorge       Tarney
# 8      Eunice Blakebrough      Eunice  Blakebrough
# 9   Kristopher Frankcombe  Kristopher   Frankcombe
# 10           Palm Domotor        Palm      Domotor
# 11          Luz Lansdowne         Luz    Lansdowne
# 12         Modestia Keble    Modestia        Keble
# 13           Stacee Bovis      Stacee        Bovis
# 14              Eden Wace        Eden         Wace
# 15        Tobias Sherburn      Tobias     Sherburn
# 16         Clair Skillern       Clair     Skillern
# ...

# %%
# Gender
# Change missing gender to Other
df = df.fillna(value={'gender':'Other', 'email':' '})
df
# Out:
#                 full_name  first_name    last_name  \
# 0         Mariel Finnigan      Mariel     Finnigan
# 1           Kenyon Possek      Kenyon       Possek
# 2          Lalo Manifould        Lalo    Manifould
# 3          Nickola Carous     Nickola       Carous
# 4           Norman Dubbin      Norman       Dubbin
# 5            Hasty Perdue       Hasty       Perdue
# 6          Franz Castello       Franz     Castello
# 7            Jorge Tarney       Jorge       Tarney
# 8      Eunice Blakebrough      Eunice  Blakebrough
# 9   Kristopher Frankcombe  Kristopher   Frankcombe
# 10           Palm Domotor        Palm      Domotor
# 11          Luz Lansdowne         Luz    Lansdowne
# 12         Modestia Keble    Modestia        Keble
# 13           Stacee Bovis      Stacee        Bovis
# 14              Eden Wace        Eden         Wace
# 15        Tobias Sherburn      Tobias     Sherburn
# 16         Clair Skillern       Clair     Skillern
# ...
